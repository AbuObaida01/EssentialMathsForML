# %% [markdown]
# <a href="https://colab.research.google.com/github/AbuObaida01/EssentialMathsForML/blob/main/EssentialMathsForML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lecture 01: Vectors in Machine Learning

# %%
import numpy as np
w=np.array([1,2,3])
x=np.array([5,6,7])

# %%
print(w+x)
# Out:
# [ 6  8 10]

# %%
print(w-x)
# Out:
# [-4 -4 -4]

# %%
print(5*w)
# Out:
# [ 5 10 15]

# %%
# To find the length of the array
# len=((x1^2+x2^2+...+xn^2))root
print(np.linalg.norm(x))
# Out:
# 10.488088481701515

# %%
print(np.dot(w,x))
# Out:
# 38
